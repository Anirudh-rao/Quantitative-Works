# %% [markdown]
# # 1. Assignment  Operators

# %%
print('Addition: ', 1 + 2)
print('Subtraction: ', 2 - 1)
print('Multiplication: ', 2 * 3)
# Out:
# Addition:  3
# Subtraction:  1
# Multiplication:  6

# %%
print('Division: ', 4 / 2)
print('Division: ', 6 / 2)
print('Division: ', 7 / 2)
# Out:
# Division:  2.0
# Division:  3.0
# Division:  3.5

# %%
print('Division without the remainder: ', 7 // 2)
print('Modulus: ', 3 % 2)                           # Gives the remainder
print('Division without the remainder: ', 7 // 3)
print('Exponential: ', 3 ** 2)
# Out:
# Division without the remainder:  3
# Modulus:  1
# Division without the remainder:  2
# Exponential:  9

# %%
print('Floating Number,PI', 3.14)
print('Floating Number, gravity', 9.81)
# Out:
# Floating Number,PI 3.14
# Floating Number, gravity 9.81

# %%
print('Complex number: ', 1+1j)
print('Multiplying complex number: ', (1+1j) * (1-1j))
# Out:
# Complex number:  (1+1j)
# Multiplying complex number:  (2+0j)

# %%
a = 3  # a is a variable name and 3 is an integer data type
b = 2  # b is a variable name and 3 is an integer data type

# %%
total = a + b
diff = a - b
product = a * b
division = a / b
remainder = a % b
floor_division = a // b
exponential = a ** b

# %%
print(total)  # if you don't label your print with some string, you never know from where is  the result is coming
print('a + b = ', total)
print('a - b = ', diff)
print('a * b = ', product)
print('a / b = ', division)
print('a % b = ', remainder)
print('a // b = ', floor_division)
print('a ** b = ', exponential)
# Out:
# 5
# a + b =  5
# a - b =  1
# a * b =  6
# a / b =  1.5
# a % b =  1
# a // b =  1
# a ** b =  9

# %%
# Declaring values and organizing them together
num_one = 3
num_two = 4

# %%
# Arithmetic operations
total = num_one + num_two
diff = num_two - num_one
product = num_one * num_two
div = num_two / num_two
remainder = num_two % num_one

# %%
# Printing values with label
print('total: ', total)
print('difference: ', diff)
print('product: ', product)
print('division: ', div)
print('remainder: ', remainder)
# Out:
# total:  7
# difference:  1
# product:  12
# division:  1.0
# remainder:  1

# %%
# Calculating area of a circle
radius = 10                                 # radius of a circle
# two * sign means exponent or power
area_of_circle = 3.14 * radius ** 2
print('Area of a circle:', area_of_circle)
# Out:
# Area of a circle: 314.0

# %%
# Calculating area of a rectangle
length = 10
width = 20
area_of_rectangle = length * width
print('Area of rectangle:', area_of_rectangle)
# Out:
# Area of rectangle: 200

# %%
# Calculating a weight of an object
mass = 75
gravity = 9.81
weight = mass * gravity
print(weight, 'N')
# Out:
# 735.75 N

# %% [markdown]
# # 2. Comparision Operators

# %%
print(3 > 2)     # True, because 3 is greater than 2
print(3 >= 2)    # True, because 3 is greater than 2
print(3 < 2)     # False,  because 3 is greater than 2
print(2 < 3)     # True, because 2 is less than 3
print(2 <= 3)    # True, because 2 is less than 3
print(3 == 2)    # False, because 3 is not equal to 2
print(3 != 2)    # True, because 3 is not equal to 2
print(len('mango') == len('avocado'))  # False
print(len('mango') != len('avocado'))  # True
print(len('mango') < len('avocado'))   # True
print(len('milk') != len('meat'))      # False
print(len('milk') == len('meat'))      # True
print(len('tomato') == len('potato'))  # True
print(len('python') > len('dragon'))   # False
# Out:
# True
# True
# False
# True
# True
# False
# True
# False
# True
# True
# False
# True
# True
# False

# %%
# Boolean comparison
print('True == True: ', True == True)
print('True == False: ', True == False)
print('False == False:', False == False)
print('True and True: ', True and True)
print('True or False:', True or False)
# Out:
# True == True:  True
# True == False:  False
# False == False: True
# True and True:  True
# True or False: True

# %% [markdown]
# In addition to the above comparison operator Python uses:
#
# 1. is: Returns true if both variables are the same object(x is y)
# 2. is not: Returns true if both variables are not the same object(x is not y)
# in: Returns True if the queried list contains a certain item(x in y)
# not in: Returns True if the queried list doesn't have a certain item(x not in y)

# %%
# Another way comparison
# True - because the data values are the same
print('1 is 1', 1 is 1)
print('1 is not 2', 1 is not 2)           # True - because 1 is not 2
print('A in Asabeneh', 'A' in 'Asabeneh')  # True - A found in the string
print('B in Asabeneh', 'B' in 'Asabeneh')  # False -there is no uppercase B
# True - because coding for all has the word coding
print('coding' in 'coding for all')
print('a in an:', 'a' in 'an')      # True
print('4 is 2 ** 2:', 4 is 2 ** 2)   # True
# Out:
# 1 is 1 True
# 1 is not 2 True
# A in Asabeneh True
# B in Asabeneh False
# True
# a in an: True
# 4 is 2 ** 2: True
# <>:3: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:4: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
# <>:10: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:3: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:4: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
# <>:10: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# /var/folders/zb/bl3vjblx59ggp4ygks32q_7r0000gn/T/ipykernel_41220/3282317992.py:3: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   print('1 is 1', 1 is 1)
# /var/folders/zb/bl3vjblx59ggp4ygks32q_7r0000gn/T/ipykernel_41220/3282317992.py:4: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
#   print('1 is not 2', 1 is not 2)           # True - because 1 is not 2
# /var/folders/zb/bl3vjblx59ggp4ygks32q_7r0000gn/T/ipykernel_41220/3282317992.py:10: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   print('4 is 2 ** 2:', 4 is 2 ** 2)   # True

# %%
print(3 > 2 and 4 > 3)  # True - because both statements are true
print(3 > 2 and 4 < 3)  # False - because the second statement is false
print(3 < 2 and 4 < 3)  # False - because both statements are false
print(3 > 2 or 4 > 3)  # True - because both statements are true
print(3 > 2 or 4 < 3)  # True - because one of the statement is true
print(3 < 2 or 4 < 3)  # False - because both statements are false
print(not 3 > 2)     # False - because 3 > 2 is true, then not True gives False
print(not True)      # False - Negation, the not operator turns true to false
print(not False)     # True
print(not not True)  # True
print(not not False)  # False
# Out:
# True
# False
# False
# True
# True
# False
# False
# False
# True
# True
# False
